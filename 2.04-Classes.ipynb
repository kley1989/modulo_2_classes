# %% [markdown]
# > Projeto Desenvolve <br>
# Programação Intermediária com Python <br>
# Profa. Camila Laranjeira (mila@projetodesenvolve.com.br) <br>
#
# # 2.4 - Classes, atributos e métodos

# %% [markdown]
# ## Exercícios
#
# #### Q1.
# Vamos criar aos pouquinhos uma classe Evento que registra eventos de um calendário. Pra começar, nessa questão você deve:
#
# * Criar uma classe chamada Evento
# * Adicionar um atributo de classe `total_eventos` que será usado para contar o número total de eventos (instâncias de classe) criadas.
# * Implemente o método construtor que deve receber os parâmetros `titulo` (`string`), `data_hora` (`datetime`), `descrição` (`string`). Crie e inicialize um atributo de instância para cada um dos parâmetros citados.
# * O construtor também deve inicializar um atributo de instância `is_concluido = False`. Esse atributo será utilizado mais à frente.
# * No construtor você também deve incrementar o atributo de classe `total_eventos` em 1 a cada nova instância criada.
#
# Teste o seu código criando duas diferentes instâncias de evento (preencha os atributos como quiser) e imprimindo todos os seus atributos (de classe e de instância).
#
# > Consulte [este tutorial biblioteca `datetime`](https://www.w3schools.com/python/python_datetime.asp) caso não esteja familiarizado.

# %%
from datetime import datetime

class Evento:
    # Atributo de classe: compartilhado por todos os eventos criados
    total_eventos = 0

    def __init__(self, titulo, data_hora, descricao):
        # Atributos de instância: cada evento tem os seus próprios
        self.titulo = titulo
        self.data_hora = data_hora
        self.descricao = descricao
        self.is_concluido = False # Começa sempre como não concluído
        
        # Cada vez que um novo evento nasce, somamos +1 no contador global
        Evento.total_eventos += 1

# --- TESTE DA ETAPA 1 ---
# Criando dois exemplos (instâncias)
e1 = Evento("Aula de Python", datetime(2023, 5, 20), "Aprender sobre classes")
e2 = Evento("Projeto Final", datetime(2025, 12, 10), "Entrega do labirinto")

print(f"Evento 1: {e1.titulo}")
print(f"Evento 2: {e2.titulo}")
print(f"Total de eventos criados até agora: {Evento.total_eventos}")
# Out:
# Evento 1: Aula de Python
# Evento 2: Projeto Final
# Total de eventos criados até agora: 2

# %% [markdown]
# #### Q2.
# Agora vamos adicionar métodos à nossa classe. Lembre dos diferentes decoradores que aprendemos. Você deve redefinir a classe com os seguintes métodos:
# * Um método `isConcluido()` que avalia se a `data_hora` do evento é menor que `datetime.now()` (a data e hora atual). Em caso positivo, atualiza o atributo de instância `is_concluido` para o valor `True`.
# * Um método de classe `num_eventos()` que retorna o valor do atributo de classe `total_eventos`.
# * Um método estático `valida_evento(nome, data_hora, descricao)` que recebe os atributos de um evento e testa os tipos de cada variável, retornando `True` caso todos estejam corretos e `False` caso contrário. Para o teste, use a função nativa do Python [`isinstance`](https://www.w3schools.com/python/ref_func_isinstance.asp).
#
# Para testar sua classe atualizada:
# * Crie uma instância de Evento com valor passado e chame o método `isConcluido()` para a instância criada. Em seguida imprima o atributo `is_concluido`.
# * Invoque o método de classe `num_eventos()` a partir da classe Evento (ou seja, sem criar nenhuma instância).
# * Chame o método estático `valida_evento()` a partir da classe Evento. Experimente passar valores corretos e incorretos.

# %%
class Evento:
    total_eventos = 0

    def __init__(self, titulo, data_hora, descricao):
        self.titulo = titulo
        self.data_hora = data_hora
        self.descricao = descricao
        self.is_concluido = False
        Evento.total_eventos += 1

    # 1. Método de Instância: Verifica se o compromisso já passou da hora
    def isConcluido(self):
        if self.data_hora < datetime.now():
            self.is_concluido = True
        return self.is_concluido

    # 2. Método de Classe: Uma forma elegante de ler o contador global
    @classmethod
    def num_eventos(cls):
        return cls.total_eventos

    # 3. Método Estático: Verifica se os dados que você digitou são do tipo certo
    @staticmethod
    def valida_evento(titulo, data_hora, descricao):
        return isinstance(titulo, str) and isinstance(data_hora, datetime) and isinstance(descricao, str)

# --- TESTE DA ETAPA 2 ---
evento_teste = Evento("Médico", datetime(2020, 1, 1), "Consulta de rotina")
print(f"O evento já passou? {evento_teste.isConcluido()}")
print(f"Status is_concluido: {evento_teste.is_concluido}")
print(f"Quantos eventos temos? {Evento.num_eventos()}")
print(f"Os dados são válidos? {Evento.valida_evento('Teste', datetime.now(), 'Desc')}")
# Out:
# O evento já passou? True
# Status is_concluido: True
# Quantos eventos temos? 1
# Os dados são válidos? True

# %% [markdown]
# #### Q3.
#
# Vamos incluir métodos mágicos! ✨🪄🔮
#
# Redefina a classe incluindo":
# * Método `__str__` que imprime os atributos do evento na forma `"Evento: titulo, Data: data_hora, Descrição: descricao, Concluido: is_concluido"`.
# * Implemente os métodos de comparação `__eq__`, `__ne__`, `__lt__`, `__le__`, `__gt__` e `__ge__` para comparar eventos baseados no atributo `data_hora`. Esses métodos devem comparar duas instâncias de Evento e retornar os resultados apropriados (`True` ou `False`).
#
# Para testar, crie duas instâncias de Evento com datas diferentes. Imprima as instâncias com a função `print()` e apresente o resultado das comparações entre eventos (`==`, `!=`, `<`, `<=`, `>`, `>=`).

# %%
class Evento:
    total_eventos = 0

    def __init__(self, titulo, data_hora, descricao):
        self.titulo = titulo
        self.data_hora = data_hora
        self.descricao = descricao
        self.is_concluido = False
        Evento.total_eventos += 1

    def isConcluido(self):
        if self.data_hora < datetime.now():
            self.is_concluido = True
        return self.is_concluido

    @classmethod
    def num_eventos(cls):
        return cls.total_eventos

    @staticmethod
    def valida_evento(titulo, data_hora, descricao):
        return isinstance(titulo, str) and isinstance(data_hora, datetime) and isinstance(descricao, str)

    # MÉTODO MÁGICO: Transforma o objeto em texto legível para o print()
    def __str__(self):
        return f"Evento: {self.titulo}, Data: {self.data_hora}, Descrição: {self.descricao}, Concluido: {self.is_concluido}"

    # MÉTODOS MÁGICOS DE COMPARAÇÃO: Comparam as datas dos eventos
    def __eq__(self, outro): return self.data_hora == outro.data_hora
    def __ne__(self, outro): return self.data_hora != outro.data_hora
    def __lt__(self, outro): return self.data_hora < outro.data_hora
    def __le__(self, outro): return self.data_hora <= outro.data_hora
    def __gt__(self, outro): return self.data_hora > outro.data_hora
    def __ge__(self, outro): return self.data_hora >= outro.data_hora

# --- TESTE FINAL ---
ev1 = Evento("Festa", datetime(2025, 1, 1), "Ano novo")
ev2 = Evento("Trabalho", datetime(2025, 5, 1), "Dia do trabalhador")

print(ev1) # Imprime graças ao __str__
print(ev2)

print(f"O evento 1 é antes do evento 2? {ev1 < ev2}")
print(f"As datas são iguais? {ev1 == ev2}")
# Out:
# Evento: Festa, Data: 2025-01-01 00:00:00, Descrição: Ano novo, Concluido: False
# Evento: Trabalho, Data: 2025-05-01 00:00:00, Descrição: Dia do trabalhador, Concluido: False
# O evento 1 é antes do evento 2? True
# As datas são iguais? False

# %%
# Certifique-se de que a classe Evento já foi definida acima
if __name__ == "__main__":
    from datetime import datetime

    print("--- 1. TESTANDO MÉTODOS ESTÁTICOS E DE CLASSE ---")
    # Testando o método estático sem precisar criar um objeto [2]
    dados_validos = Evento.valida_evento("Aula Python", datetime(2023, 10, 10), "Estudo")
    print(f"Os dados passados são válidos? {dados_validos}")

    # Consultando o total de eventos inicial (deve ser 0 se nada foi criado ainda) [2]
    print(f"Total de eventos criados: {Evento.num_eventos()}\n")

    print("--- 2. CRIANDO INSTÂNCIAS E TESTANDO ATRIBUTOS ---")
    # Criando duas instâncias com datas diferentes para comparação [1, 3]
    ev1 = Evento("Reunião de Trabalho", datetime(2023, 1, 1, 10, 0), "Discussão de metas")
    ev2 = Evento("Festa de Aniversário", datetime(2025, 12, 25, 20, 0), "Comemoração")

    # Imprimindo as instâncias (isso testa o seu método mágico __str__) [2, 3]
    print(ev1)
    print(ev2)

    print("\n--- 3. TESTANDO LÓGICA DE CONCLUSÃO ---")
    # Chamando o método isConcluido para o evento que já passou (ev1) [2]
    ev1.isConcluido()
    print(f"O evento 1 (data passada) está concluído? {ev1.is_concluido}")
    
    # Verificando o evento futuro (ev2)
    ev2.isConcluido()
    print(f"O evento 2 (data futura) está concluído? {ev2.is_concluido}")

    print("\n--- 4. TESTANDO COMPARAÇÕES (MÉTODOS MÁGICOS) ---")
    # O exercício exige testar as comparações baseadas na data_hora [3]
    print(f"Evento 1 é igual ao Evento 2? (==) {ev1 == ev2}")
    print(f"Evento 1 é diferente do Evento 2? (!=) {ev1 != ev2}")
    print(f"Evento 1 é anterior ao Evento 2? (<) {ev1 < ev2}")
    print(f"Evento 1 é posterior ao Evento 2? (>) {ev1 > ev2}")

    print(f"\nTotal final de eventos criados: {Evento.num_eventos()} [2]")
# Out:
# --- 1. TESTANDO MÉTODOS ESTÁTICOS E DE CLASSE ---
# Os dados passados são válidos? True
# Total de eventos criados: 2
#
# --- 2. CRIANDO INSTÂNCIAS E TESTANDO ATRIBUTOS ---
# Evento: Reunião de Trabalho, Data: 2023-01-01 10:00:00, Descrição: Discussão de metas, Concluido: False
# Evento: Festa de Aniversário, Data: 2025-12-25 20:00:00, Descrição: Comemoração, Concluido: False
#
# --- 3. TESTANDO LÓGICA DE CONCLUSÃO ---
# O evento 1 (data passada) está concluído? True
# O evento 2 (data futura) está concluído? True
#
# --- 4. TESTANDO COMPARAÇÕES (MÉTODOS MÁGICOS) ---
# Evento 1 é igual ao Evento 2? (==) False
# Evento 1 é diferente do Evento 2? (!=) True
# Evento 1 é anterior ao Evento 2? (<) True
# Evento 1 é posterior ao Evento 2? (>) False
#
# Total final de eventos criados: 4 [2]
